# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
URL = 'https://www.iata.org/en/publications/directories/cargolink/directory/'

#page = requests.get(url)

#soup = BeautifulSoup(page.text, 'html')

#print(soup)

# %%
#Headers for requests
HEADERS = ({'User-Agent ':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36 Edg/134.0.0.0', 'Accept-Language': 'en-US, en;q=0.5' })

# %%
#HTTP Requests
webpage = requests.get(URL, headers=HEADERS)

# %%
webpage
# Out:
# <Response [200]>

# %%
type(webpage.content)
# Out:
# bytes

# %%
# Soup agent containing all data
soup = BeautifulSoup(webpage.content, "html.parser")

# %%
# Fetch links as List of tag objects
links = soup.find_all("a", attrs={'class': '<table class ="datatable">'})

# %%
links
# Out:
# []

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="on-page-editor" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>IATA - CargoLink Directory</title>
# <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/site.webmanifest" rel="manifest"/>
# <link color="#1e32fa" href="/safari-pinned-tab.svg" rel="mask-icon"/>
# <meta content="#da532c" name="msapplication-TileColor"/>
# <meta content="#ffffff" name="theme-color"/>
# <meta content="Search for your ideal supplier or business partner using CargoLink. Get details of more than 6,000 freight forwarders, airlines, airports and other industry professionals. " name="description">
# ...

# %% [raw]
# #soup.find_all('table')[1]

# %%
#<table class ="datatable">
#<caption>
# Out:
#   Cell In[6], line 1
#     <table class="datatable">
#     ^
# SyntaxError: invalid syntax

# %%
soup.find_all('table')[1]
